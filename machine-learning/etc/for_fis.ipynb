# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
clim = pd.read_csv('D:/Datasets/For fuzzy/climate_change.csv')

# %%
print(clim.head(4))
clim.tail(4)
# Out:
# Year  Month    MEI     CO2      CH4      N2O   CFC-11   CFC-12        TSI  \
# 0  1983      5  2.556  345.96  1638.59  303.677  191.324  350.113  1366.1024
# 1  1983      6  2.167  345.52  1633.71  303.746  192.057  351.848  1366.1208
# 2  1983      7  1.741  344.15  1633.22  303.795  192.818  353.725  1366.2850
# 3  1983      8  1.130  342.25  1631.35  303.839  193.602  355.633  1366.4202
#
#    Aerosols   Temp
# 0    0.0863  0.109
# 1    0.0794  0.118
# 2    0.0731  0.137
# 3    0.0673  0.176
#      Year  Month    MEI     CO2      CH4      N2O   CFC-11   CFC-12  \
# 304  2008      9 -0.643  383.09  1795.08  321.529  244.083  535.048
# 305  2008     10 -0.780  382.99  1814.18  321.796  244.080  534.927
# 306  2008     11 -0.621  384.13  1812.37  322.013  244.225  534.906
# 307  2008     12 -0.666  385.56  1812.88  322.182  244.204  535.005
#
#            TSI  Aerosols   Temp
# 304  1365.6647    0.0043  0.378
# 305  1365.6759    0.0046  0.440
# 306  1365.7065    0.0048  0.394
# ...

# %%
clim.describe()
# Out:
#               Year       Month         MEI         CO2          CH4  \
# count   308.000000  308.000000  308.000000  308.000000   308.000000
# mean   1995.662338    6.551948    0.275555  363.226753  1749.824513
# std       7.423197    3.447214    0.937918   12.647125    46.051678
# min    1983.000000    1.000000   -1.635000  340.170000  1629.890000
# 25%    1989.000000    4.000000   -0.398750  353.020000  1722.182500
# 50%    1996.000000    7.000000    0.237500  361.735000  1764.040000
# 75%    2002.000000   10.000000    0.830500  373.455000  1786.885000
# max    2008.000000   12.000000    3.001000  388.500000  1814.180000
#
#               N2O      CFC-11      CFC-12          TSI    Aerosols        Temp
# count  308.000000  308.000000  308.000000   308.000000  308.000000  308.000000
# mean   312.391834  251.973068  497.524782  1366.070759    0.016657    0.256776
# std      5.225131   20.231783   57.826899     0.399610    0.029050    0.179090
# ...

# %%
plt.figure()
plt.scatter(clim['Aerosols'], clim['Temp'])
plt.show()

# %%
plt.scatter(clim['CO2'], clim['Temp'])
plt.xlabel('CO2 (ppm)')
plt.ylabel('TempRise (degC)')
plt.title('CO2 vs TempRise')
plt.show()

# %%
plt.scatter(clim['CFC-12'], clim['Temp'])
plt.xlabel('CFC-12 (ppb)')
plt.ylabel('TempRise (degC)')
plt.title('CFC-12 vs TempRise')
plt.show()

# %%
plt.scatter(clim['N2O'], clim['Temp'])
plt.xlabel('N2O (ppm)')
plt.ylabel('TempRise (degC)')
plt.title('N2O vs TempRise')
plt.show()

# %%
plt.scatter(clim['MEI'], clim['Temp'])
plt.show()

# %%
clim.to_excel('D:/Datasets/For fuzzy/climate_change.xlsx')

# %%
clim.sort_values(['MEI'])
# Out:
#      Year  Month    MEI     CO2      CH4      N2O   CFC-11   CFC-12  \
# 298  2008      3 -1.635  385.97  1792.84  321.295  245.430  535.979
# 64   1988      9 -1.586  349.03  1701.35  306.611  249.389  451.255
# 66   1988     11 -1.468  350.15  1719.88  307.274  251.664  456.226
# 297  2008      2 -1.402  385.73  1803.45  321.345  245.898  536.484
# 63   1988      8 -1.374  350.66  1691.77  306.522  248.187  449.005
# ..    ...    ...    ...     ...      ...      ...      ...      ...
# 178  1998      3  2.748  367.13  1774.54  313.346  266.593  535.421
# 170  1997      7  2.756  364.34  1751.61  312.647  267.784  532.827
# 177  1998      2  2.777  365.98  1766.01  313.512  266.978  535.561
# 172  1997      9  3.000  360.31  1775.56  312.845  267.414  534.415
# 171  1997      8  3.001  362.20  1750.23  312.702  267.441  533.315
#
#            TSI  Aerosols   Temp
# 298  1365.6726    0.0034  0.447
# 64   1366.4616    0.0069  0.149
# 66   1366.2957    0.0068  0.027
# ...

# %%
clim.describe()
# Out:
#               Year       Month         MEI         CO2          CH4  \
# count   308.000000  308.000000  308.000000  308.000000   308.000000
# mean   1995.662338    6.551948    0.275555  363.226753  1749.824513
# std       7.423197    3.447214    0.937918   12.647125    46.051678
# min    1983.000000    1.000000   -1.635000  340.170000  1629.890000
# 25%    1989.000000    4.000000   -0.398750  353.020000  1722.182500
# 50%    1996.000000    7.000000    0.237500  361.735000  1764.040000
# 75%    2002.000000   10.000000    0.830500  373.455000  1786.885000
# max    2008.000000   12.000000    3.001000  388.500000  1814.180000
#
#               N2O      CFC-11      CFC-12          TSI    Aerosols        Temp
# count  308.000000  308.000000  308.000000   308.000000  308.000000  308.000000
# mean   312.391834  251.973068  497.524782  1366.070759    0.016657    0.256776
# std      5.225131   20.231783   57.826899     0.399610    0.029050    0.179090
# ...

# %%
clim_test = clim[['MEI', 'CO2', 'N2O', 'CFC-12', 'Temp']]

# %%
clim_data = clim[['CO2','CH4', 'N2O', 'CFC-12', 'Temp']]

# %%
clim_test.to_excel('D:/Datasets/For fuzzy/clim_test.xlsx')

# %%
clim_data.to_excel('D:/Datasets/For fuzzy/clim_data.xlsx')

# %%
clim_data.describe()
# Out:
#               CO2          CH4         N2O      CFC-12        Temp
# count  308.000000   308.000000  308.000000  308.000000  308.000000
# mean   363.226753  1749.824513  312.391834  497.524782    0.256776
# std     12.647125    46.051678    5.225131   57.826899    0.179090
# min    340.170000  1629.890000  303.677000  350.113000   -0.282000
# 25%    353.020000  1722.182500  308.111500  472.410750    0.121750
# 50%    361.735000  1764.040000  311.507000  528.356000    0.248000
# 75%    373.455000  1786.885000  316.979000  540.524250    0.407250
# max    388.500000  1814.180000  322.182000  543.813000    0.739000
